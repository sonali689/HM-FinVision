# %%
# %pip install aleatory
from aleatory.processes import Vasicek
process = Vasicek(theta=0.5, mu=-10.0, sigma=2.0, initial=1.0, T=20.0)
process.draw(n=200, N=200, envelope=False, title='Vasicek Process')
import matplotlib.pyplot as plt
plt.show()
# Out:
# Requirement already satisfied: aleatory in c:\users\dubey\anaconda\lib\site-packages (0.4.0)
# Requirement already satisfied: pandas>=1.5.2 in c:\users\dubey\appdata\roaming\python\python311\site-packages (from aleatory) (2.2.2)
# Requirement already satisfied: numpy>=1.23.5 in c:\users\dubey\appdata\roaming\python\python311\site-packages (from aleatory) (1.26.4)
# Requirement already satisfied: scipy>=1.9.3 in c:\users\dubey\appdata\roaming\python\python311\site-packages (from aleatory) (1.14.0)
# Requirement already satisfied: matplotlib>=3.6.2 in c:\users\dubey\appdata\roaming\python\python311\site-packages (from aleatory) (3.9.1)
# Requirement already satisfied: statsmodels>=0.13.5 in c:\users\dubey\anaconda\lib\site-packages (from aleatory) (0.14.0)
# Requirement already satisfied: parameterized>=0.8.1 in c:\users\dubey\anaconda\lib\site-packages (from aleatory) (0.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dubey\appdata\roaming\python\python311\site-packages (from matplotlib>=3.6.2->aleatory) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\dubey\appdata\roaming\python\python311\site-packages (from matplotlib>=3.6.2->aleatory) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dubey\appdata\roaming\python\python311\site-packages (from matplotlib>=3.6.2->aleatory) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dubey\appdata\roaming\python\python311\site-packages (from matplotlib>=3.6.2->aleatory) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\dubey\appdata\roaming\python\python311\site-packages (from matplotlib>=3.6.2->aleatory) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\dubey\appdata\roaming\python\python311\site-packages (from matplotlib>=3.6.2->aleatory) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dubey\appdata\roaming\python\python311\site-packages (from matplotlib>=3.6.2->aleatory) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dubey\appdata\roaming\python\python311\site-packages (from matplotlib>=3.6.2->aleatory) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dubey\appdata\roaming\python\python311\site-packages (from pandas>=1.5.2->aleatory) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dubey\appdata\roaming\python\python311\site-packages (from pandas>=1.5.2->aleatory) (2024.1)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\dubey\anaconda\lib\site-packages (from statsmodels>=0.13.5->aleatory) (0.5.3)
# Requirement already satisfied: six in c:\users\dubey\appdata\roaming\python\python311\site-packages (from patsy>=0.5.2->statsmodels>=0.13.5->aleatory) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Definition
#
# The Vasicek model specifies that the instantaneous interest rate is defined by a stochastic process which can be defined by the following Stochastic Differential Equation (SDE)
#
#
# \begin{equation}
# dX_t = \theta (\mu - X_t) dt + \sigma dW_t, \quad t >0,
# \end{equation}
#
#
# with initial condition  $X_0 =x_0\in\mathbb{R}$, and where $W_t$ is a standard Brownian motion, and the three parameters are constants:
#
# - $\theta>0$ : speed or mean reversion coefficient
# - $\mu \in \mathbb{R}$ : long term mean
# - $\sigma>0$ : volatility
#
#
#
# In order to find the solution to this SDE, let us set the function $f(t,x) = x e^{\theta t}$. Then, Ito's formula implies
#
#
# \begin{align*}
# X_te^{\theta t} &= x_0 +\int_0^t X_s \theta e^{\theta s}ds + \int_0^t e^{\theta s}dX_s \\
# & = x_0 + \int_0^t \left[ \theta X_s  e^{\theta s}  +\theta e^{\theta s}(\mu - X_s)\right] ds + \int_0^t e^{\theta s}\sigma dW_s\\
# & = x_0 + \int_0^t \left[ \theta e^{\theta s}\mu\right] ds + \int_0^t e^{\theta s}\sigma dW_s\\
# & = x_0 + \mu(e^{\theta t} - 1) + \int_0^t e^{\theta s}\sigma dW_s.
# \end{align*}
#
#
# Thus
#
# \begin{equation}
# X_t = x_0e^{-\theta t} +  \mu(1- e^{-\theta t})  + \sigma \int_0^t e^{-\theta (t-s)}dW_s.
# \end{equation}

# %% [markdown]
# ### Expectation and Variance
#
# For each $t>0$, the conditional marginal $X_t|X_0$ from a Vacisek process satisfies
#
# \begin{equation*}
# \mathbf{E} [X_t ] = \mathbb{E}[X_t|X_0] = x_0e^{-\theta t} +  \mu(1- e^{-\theta t}),
# \end{equation*}
#
# and
#
# \begin{equation*}
# \mathbf{Var} [X_t ] = \mathbb{Var} [X_t |X_0] =  \frac{\sigma^2}{ 2\theta} (1- e^{-2\theta t}).
# \end{equation*}
#
# To obtain the expectation we simply use the linearity of the expectation and the fact that the Ito integral in equation (2) is a martingale. Similarly, for the variance we  use basic properties of the variance and the isometry property of the Ito integral.

# %% [markdown]
# ### Python Implementation
#
# So, for given $x_0, \theta>0, \mu, \sigma>0$ and $t,s>0$ You will implement the above formulas for the expectation, variance, and covariance as follows.

# %%
# Vasicek model formulas for expectation, variance, and covariance
import numpy as np
def vasicek_expectation(x0, theta, mu, sigma, t):
    return mu + (x0 - mu) * np.exp(-theta * t)

def vasicek_variance(theta, sigma, t):
    return (sigma ** 2 / (2 * theta)) * (1 - np.exp(-2 * theta * t))

def vasicek_covariance(theta, sigma, t, s):
    return (sigma ** 2 / (2 * theta)) * np.exp(-theta * abs(t - s)) * (1 - np.exp(-2 * theta * min(t, s)))

#if
x0, theta, mu, sigma = 0.03, 0.1, 0.05, 0.02 
t, s = 1, 2 

expectation = vasicek_expectation(x0, theta, mu, sigma, t)
variance = vasicek_variance(theta, sigma, t)
covariance = vasicek_covariance(theta, sigma, t, s)

print(f"Expectation: {expectation}")
print(f"Variance: {variance}")
print(f"Covariance: {covariance}")
# Out:
# Expectation: 0.03190325163928081
# Variance: 0.0003625384938440364
# Covariance: 0.00032803839470848346

# %% [markdown]
# ### Marginal Distributions in Python
#
# Knowing the distribution –with its corresponding parameters– of the marginal distributions allows us to reproduce them with `Python`.
#
# One way to do this is by using the object  `norm`  from the library `scipy.stats`.  The next cell shows how to create $X_1$ using this method.

# %%
from scipy.stats import norm
import numpy as np
#### Calculate Mean and Varaince of Normal Distribution with initial values of X0,mu,sigma,t

def compute_mean_variance(x0, mu, sigma, theta, t):
    mean = x0 * np.exp(-theta * t) + mu * (1 - np.exp(-theta * t))
    variance = (sigma**2 / (2 * theta)) * (1 - np.exp(-2 * theta * t))
    return mean, variance

x0, mu, sigma, theta, t = 1.0, 10.0, 0.5, 1.0, 1.0
mean, variance = compute_mean_variance(x0, mu, sigma, theta, t)
print(f"Mean: {mean}, Variance: {variance}")
# Out:
# Mean: 6.6890850294570185, Variance: 0.10808308959542341

# %% [markdown]
# ### Probability Density Functions
#
# The probability density function (pdf) of the marginal distribution $X_t$ is given by the following expression
# \begin{equation*}
# f(x, t; \theta,  \mu, \sigma, x_0) = \dfrac{1}{ \frac{\sigma}{ \sqrt{2\theta}}  \sqrt{ (1- e^{-2\theta t})} \sqrt{2 \pi }}\exp\left\{ -\dfrac{1}{2} \left(\dfrac{x- [x_0e^{-\theta t} +  \mu(1- e^{-\theta t})] }{ \frac{\sigma}{ \sqrt{2\theta}}  \sqrt{ (1- e^{-2\theta t})}}\right)^2  \right\}, \qquad \forall x\in\mathbb{R}, t>0.
# \end{equation*}

# %% [markdown]
# First we consider the process
# `Vasicek(theta=1.0, mu=10.0, sigma=0.5, initial=1.0)` and plot the marginal density of $X_1$.
# Note that the mean is still far from the long term mean $\mu=10$. Code it and plot the Graph of Distribution
# '''
# process = Vasicek(theta=1.0, mu=10.0, sigma=0.5, initial=1.0)
# X_1 = process.get_marginal(t=1)
# ''''

# %%
'''process = Vasicek(theta=1.0, mu=10.0, sigma=0.5, initial=1.0)
X_1 = process.get_marginal(t=1)
'''''
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def vasicek_pdf(x, t, theta, mu, sigma, x0):
    mean = x0 * np.exp(-theta * t) + mu * (1 - np.exp(-theta * t))
    variance = (sigma**2 / (2 * theta)) * (1 - np.exp(-2 * theta * t))
    std_dev = np.sqrt(variance)
    return norm.pdf(x, loc=mean, scale=std_dev)

theta = 1.0
mu = 10.0
sigma = 0.5
x0 = 1.0
t = 1.0

x_values = np.linspace(0, 15, 500)

pdf_values = vasicek_pdf(x_values, t, theta, mu, sigma, x0)

plt.figure(figsize=(10, 6))
plt.plot(x_values, pdf_values, label=f"PDF at t={t}", color="blue")
plt.title("Marginal Density of Vasicek Process", fontsize=16)
plt.xlabel("x", fontsize=14)
plt.ylabel("Density", fontsize=14)
plt.grid(True)
plt.legend(fontsize=12)
plt.show()

# %% [markdown]
# **Plot Graphs** Dsitrbution in which Vary one at time ( sigma,mu,theta ,t ) . Vary one value taking  initial values of sigma,mu,theta,t

# %%
x0, theta, mu, sigma = 0.03, 0.1, 0.05, 0.02
t = 1

parameters = {
    "theta": np.linspace(0.05, 0.5, 10),
    "mu": np.linspace(0.03, 0.07, 10),
    "sigma": np.linspace(0.01, 0.05, 10),
    "t": np.linspace(0.5, 5, 10),
}

# Plot each case
fig, axs = plt.subplots(2, 2, figsize=(12, 10))
for ax, (param_name, values) in zip(axs.flatten(), parameters.items()):
    expectations = [vasicek_expectation(x0, theta if param_name != "theta" else val, 
                                        mu if param_name != "mu" else val, 
                                        sigma if param_name != "sigma" else val, 
                                        t if param_name != "t" else val) 
                    for val in values]
    ax.plot(values, expectations, label=f'Varying {param_name}')
    ax.set_xlabel(param_name)
    ax.set_ylabel('Expectation')
    ax.legend()
    ax.grid(True)

plt.tight_layout()
plt.show()

# %%
# Additional plots or analyses can be added here.

# %%
# Further calculations or model refinements can be implemented here.

# %%
# End of notebook. You can add summary or conclusions here.

# %%
#from aleatory.processes import Vasicek
import matplotlib.pyplot as plt
import numpy as np

process = Vasicek(theta=1.0, mu=-10.0, sigma=np.sqrt(2), initial=0.0, T=12.0)
path = process.simulate(n=1000, N=1)
ts = process.times
exp = process.marginal_expectation(ts)
plt.plot(ts, path[0], label= f'$x_0$ = 0, $\mu$ = -10')
plt.plot(ts, exp, color='grey',linewidth=2)

for x0 in [-10.0, 0.0, 10.0]:
    process = Vasicek(theta=1.0, mu=0.0, sigma=np.sqrt(2), initial=x0, T=12.0)
    path = process.simulate(n=1000, N=1)
    plt.plot(ts, path[0], label= f'$x_0$ = {x0:.0f}, $\mu$ = 0')
    exp = process.marginal_expectation(ts)
    plt.plot(ts, exp, color='grey', linewidth=2)
plt.plot(ts, exp, color='grey', label=f'$E[X_t]$')
plt.legend()
plt.title('Four Paths from the Vasicek Model\n $dX_t = \\theta(\mu - X_t) dt + \sigma dW_t$\n with $\\theta = 1, \sigma = \sqrt{2}$')
plt.show()

# %% [markdown]
# **Simulation**

# %%
process = Vasicek(theta=0.5, mu=10.0, sigma=2.0, initial=-1.0, T=20.0)
fig = process.draw(n=200, N=200, envelope=True)

# %% [markdown]
# #### The parameter $\theta$ determines the Speed of Convergence

# %%
# from aleatory.processes import Vasicek
process = Vasicek(theta=5.0, mu=10.0, sigma=2.0, initial=1.0, T=1.0)
fig = process.draw(n=100, N=100, title='Vasicek Process quickly reaching convergence to the asymptotic distribution')

# %%
import numpy as np
import matplotlib.pyplot as plt

def simulate_wiener_process(num_points, dt):
    # Generate the increments using normal distribution
    increments = np.random.normal(0, np.sqrt(dt), num_points - 1)

    # The Wiener process starts at zero, so we concatenate a 0 at the beginning
    W = np.concatenate([[0], np.cumsum(increments)])

    return W

# Simulation parameters
num_points = 1000
dt = 0.01

W = simulate_wiener_process(num_points, dt)

# Plotting the Wiener process
plt.figure(figsize=(10, 6))
plt.plot(np.arange(num_points) * dt, W)
plt.title('Wiener Process')
plt.xlabel('Time')
plt.ylabel('W(t)')
plt.grid(True)
plt.show()

# %% [markdown]
# #Plot different no. of paths by varying parameter and time interval!
